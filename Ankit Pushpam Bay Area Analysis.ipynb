# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_excel('Hayward_CA.xlsx','data')# Sheet name matches exactly the sheet that we want to open. 
df.head(1)
# Out:
#    Unnamed: 0                                Address Sold_Price  \
# 0           0  25026 Willimet Way, Hayward, CA 94544  $815,000
#
#              Sold_Date               House_Type  \
# 0  Sold on Mar 6, 2020  Single Family Residence
#
#                                             Bathroom  \
# 0  Shower(s) over Tub(s), Solid Surface,  Tile,  ...
#
#                                              Kitchen           Family_Room  \
# 0  Dishwasher, Garbage Disposal,  Microwave, Oven...  Separate Family Room
#
#                   Fire_Place         Flooring                  Laundry  \
# 0  Family Room, Wood Burning  Laminate,  Tile  Hookups Only, In Closet
#
#               Pool         Style Beds Bath   Sqft Sqft_Lot Year_Built
# 0  None, Pool - No  Contemporary    3    3  1,581    5,928       1958

# %%
#df['Address'] = df['Address'].astype(str)
df = df.drop('Unnamed: 0', axis = 1)

# %% [markdown]
# Question 1: What type of the house is most built in the Hayward town?
#
# Conclusion: Single Family Residence is the most famous house type built over in the Hayward. And the interesting fact is there there a very few building with for the built type is Business Opportunity.

# %%
Series=df['House_Type'].value_counts() 
Series.plot(kind="bar",color='b')

# %% [markdown]
# Question 2: To further explore more what style is more famous in the house type 'Single Family Residence'?
# Conclusion: In the House Type 'Single Family Residence ' the most famous style is 'customer', 'Prairie', and 'ranch'.

# %%
ct=pd.crosstab(df['House_Type'],df['Style'])
ct
# Out:
# Style                    Bungalow  Bungalow,  Contemporary  Cape Cod  \
# House_Type
# Business Opportunity            0                        0         0
# Commercial Sale                 0                        0         0
# Condominium                     0                        0         0
# Duplex                          0                        0         0
# Land                            0                        0         0
# Manufactured In Park            0                        0         0
# Residential Income              0                        0         0
# Single Family Residence        18                        1         1
# Townhouse                       0                        0         0
#
# Style                    Central -1 Zone  Contemporary  Contemporary,  Ranch  \
# House_Type
# Business Opportunity                   1             0                     0
# Commercial Sale                        0             0                     0
# Condominium                            0            22                     0
# Duplex                                 0             0                     0
# Land                                   0             0                     0
# Manufactured In Park                   0             0                     0
# Residential Income                     0             0                     0
# Single Family Residence                0            49                     1
# Townhouse                              0            30                     0
#
# Style                    Contemporary,  Traditional  \
# House_Type
# Business Opportunity                              0
# Commercial Sale                                   0
# Condominium                                       0
# Duplex                                            0
# Land                                              0
# Manufactured In Park                              0
# Residential Income                                0
# Single Family Residence                           1
# Townhouse                                         1
#
# Style                    Contemporary, Cottage/Bungalow  Cottage/Bungalow  \
# House_Type
# Business Opportunity                                  0                 0
# Commercial Sale                                       0                 0
# Condominium                                           0                 0
# Duplex                                                0                 0
# Land                                                  0                 0
# Manufactured In Park                                  0                 0
# Residential Income                                    0                 0
# Single Family Residence                               1                 4
# Townhouse                                             0                 0
#
# Style                    Craftsman  ...  Other  Other,  Ranch  Prairie  Ranch  \
# House_Type                          ...
# Business Opportunity             0  ...      0              0        0      0
# Commercial Sale                  0  ...      0              0        0      0
# Condominium                      0  ...      1              0        0      0
# Duplex                           0  ...      0              0        0      0
# Land                             0  ...      0              0        0      0
# Manufactured In Park             0  ...      0              0        0      0
# Residential Income               0  ...      0              0        0      0
# Single Family Residence          7  ...     15              1        1     39
# Townhouse                        0  ...      3              0        0      0
#
# Style                    Ranch,  Traditional  Spanish  Traditional  Unknown  \
# House_Type
# Business Opportunity                       0        0            0        0
# Commercial Sale                            0        0            0        0
# Condominium                                0        1            4        3
# Duplex                                     0        0            0        0
# Land                                       0        0            0        0
# Manufactured In Park                       0        0            0        0
# Residential Income                         0        0            0        0
# Single Family Residence                    1        1           52        5
# Townhouse                                  0        0            0        2
#
# Style                    Victorian   –
# House_Type
# Business Opportunity             0   0
# Commercial Sale                  0   1
# Condominium                      0   4
# Duplex                           0   5
# Land                             0   8
# Manufactured In Park             0  19
# Residential Income               0   8
# Single Family Residence          1  16
# Townhouse                        0   5
#
# [9 rows x 24 columns]

# %%
ct.plot.bar(stacked=True)
plt.legend(title = 'Style' ,loc = 'sks')
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Unrecognized location 'sks'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
df['Sold_Price'] = df['Sold_Price'].replace('– ', 0)
df['Sold_Price'] = df['Sold_Price'].str.replace('$', '')
df['Sold_Price'] = df['Sold_Price'].str.replace(',', '')
df['Sqft'] = df['Sqft'].replace('–', 0)
df['Sqft'] = df['Sqft'].str.replace(',', '')


df.head(20)
# Out:
#                                       Address Sold_Price  \
# 0       25026 Willimet Way, Hayward, CA 94544    815000
# 1          1757 De Pina Ln, Hayward, CA 94545    950000
# 2          23764 Nevada Rd, Hayward, CA 94541    710000
# 3            453 Redbud Ln, Hayward, CA 94541    658000
# 4        1588 Southgate St, Hayward, CA 94545    606000
# 5        22567 Arlette Ave, Hayward, CA 94541    450000
# 6             2421 Arf Ave, Hayward, CA 94545    598000
# 7         1612 East Avenue, Hayward, CA 94541    675000
# 8           1713 Calais Ct, Hayward, CA 94541    565000
# 9       28968 Guilford Ct., Hayward, CA 94544    127000
# 10        2211 Beckham Way, Hayward, CA 94541    985000
# 11          27814 Biscayne, Hayward, CA 94544    641600
# 12     652 Chevy Chase Way, Hayward, CA 94544    750000
# 13  2334 Sleepy Hollow Ave, Hayward, CA 94545    685000
# 14         29032 Guildhall, Hayward, CA 94544    289000
# 15       25347 Parklane Dr, Hayward, CA 94544    719000
# 16       25377 Parklane Dr, Hayward, CA 94544    720000
# 17      25026 Willimet Way, Hayward, CA 94544    815000
# 18         1757 De Pina Ln, Hayward, CA 94545    950000
# 19         23764 Nevada Rd, Hayward, CA 94541    710000
#
#                Sold_Date               House_Type  \
# 0    Sold on Mar 6, 2020  Single Family Residence
# 1    Sold on Mar 6, 2020  Single Family Residence
# 2    Sold on Mar 6, 2020  Single Family Residence
# 3    Sold on Mar 6, 2020  Single Family Residence
# 4    Sold on Mar 6, 2020  Single Family Residence
# 5    Sold on Mar 6, 2020  Single Family Residence
# 6    Sold on Mar 5, 2020                Townhouse
# 7    Sold on Mar 5, 2020  Single Family Residence
# 8    Sold on Mar 4, 2020                Townhouse
# 9    Sold on Mar 4, 2020     Manufactured In Park
# 10   Sold on Mar 3, 2020  Single Family Residence
# 11   Sold on Mar 2, 2020  Single Family Residence
# 12   Sold on Mar 2, 2020  Single Family Residence
# 13   Sold on Mar 2, 2020  Single Family Residence
# 14  Sold on Feb 28, 2020     Manufactured In Park
# 15  Sold on Feb 28, 2020                Townhouse
# 16  Sold on Feb 28, 2020              Condominium
# 17   Sold on Mar 6, 2020  Single Family Residence
# 18   Sold on Mar 6, 2020  Single Family Residence
# 19   Sold on Mar 6, 2020  Single Family Residence
#
#                                              Bathroom  \
# 0   Shower(s) over Tub(s), Solid Surface,  Tile,  ...
# 1                              Other, Stall Shower(s)
# 2                               Shower(s) over Tub(s)
# 3   Shower(s) over Tub(s), Solid Surface, Updated ...
# 4                                         Other,  Tub
# 5                                                   –
# 6         Shower(s) over Tub(s), Solid Surface,  Tile
# 7                               Shower(s) over Tub(s)
# 8                               Shower(s) over Tub(s)
# 9   Master - Stall Shower(s), Master - Tub, Stall ...
# 10             Stall Shower(s),  Tub, Updated Bath(s)
# 11                                    Stall Shower(s)
# 12                                                  –
# 13                              Shower(s) over Tub(s)
# 14      Master - Stall Shower(s), Solid Surface,  Tub
# 15  Double Sinks, Dual Flush Toilet,  Marble, Mast...
# 16  Double Sinks, Dual Flush Toilet,  Marble, Mast...
# 17  Shower(s) over Tub(s), Solid Surface,  Tile,  ...
# 18                             Other, Stall Shower(s)
# 19                              Shower(s) over Tub(s)
#
#                                               Kitchen  \
# 0   Dishwasher, Garbage Disposal,  Microwave, Oven...
# 1   Garbage Disposal,  Microwave,  Other, Oven Ran...
# 2   Cooktop - Electric, Oven - Built-In, Breakfast...
# 3   Garbage Disposal,  Other, Oven Range,  Refrige...
# 4   Other, Oven - Built-In, Oven Range, 220 Volt O...
# 5                               Other, Eat In Kitchen
# 6   Garbage Disposal, Oven Range,  Dryer,  Washer,...
# 7   Oven Range,  Refrigerator,  Dryer,  Washer, Co...
# 8       Dishwasher, Garbage Disposal,  Dryer,  Washer
# 9          Oven Range,  Refrigerator,  Dryer,  Washer
# 10  Cooktop - Electric, Garbage Disposal,  Microwa...
# 11  Dishwasher, Garbage Disposal,  Microwave, Oven...
# 12  Countertop - Stone, Eat In Kitchen, Kitchen/Fa...
# 13                Garbage Disposal, Countertop - Tile
# 14  Cooktop - Electric,  Dishwasher, Garbage Dispo...
# 15  Dishwasher, Garbage Disposal,  Microwave, Oven...
# 16  Dishwasher,  Microwave, Oven Range, Countertop...
# 17  Dishwasher, Garbage Disposal,  Microwave, Oven...
# 18  Garbage Disposal,  Microwave,  Other, Oven Ran...
# 19  Cooktop - Electric, Oven - Built-In, Breakfast...
#
#                   Family_Room                             Fire_Place  \
# 0        Separate Family Room              Family Room, Wood Burning
# 1                           –                                   None
# 2        Separate Family Room       Brick, Living Room, Wood Burning
# 3                           –                                   None
# 4                           –                     Brick, Family Room
# 5                           –                                  Brick
# 6                           –                     Dining Room,  None
# 7                           –                           Wood Burning
# 8                           –                                   None
# 9                           –                                   None
# 10       Separate Family Room  Family Room, Gas Burning, Living Room
# 11                          –                                   None
# 12                          –                            Family Room
# 13                          –              Living Room, Wood Burning
# 14                          –                                   None
# 15  Kitchen/Family Room Combo                                      –
# 16  Kitchen/Family Room Combo                                      –
# 17       Separate Family Room              Family Room, Wood Burning
# 18                          –                                   None
# 19       Separate Family Room       Brick, Living Room, Wood Burning
#
#                                              Flooring  \
# 0                                     Laminate,  Tile
# 1                    Carpet - Wall to Wall,  Hardwood
# 2                                            Laminate
# 3                                     Laminate,  Tile
# 4                                       Other,  Vinyl
# 5                                                Wood
# 6                                     Laminate,  Tile
# 7   Carpet - Wall to Wall,  Hardwood,  Laminate,  ...
# 8                                            Concrete
# 9                       Carpet - Wall to Wall,  Vinyl
# 10                   Carpet - Wall to Wall,  Hardwood
# 11                                    Laminate,  Tile
# 12                         Hardwood,  Laminate,  Tile
# 13                                           Hardwood
# 14                                           Laminate
# 15                                             Carpet
# 16                                             Carpet
# 17                                    Laminate,  Tile
# 18                   Carpet - Wall to Wall,  Hardwood
# 19                                           Laminate
#
#                                               Laundry  \
# 0                             Hookups Only, In Closet
# 1                             In Laundry Room,  Other
# 2                                           In Garage
# 3                                               Other
# 4                                   In Garage,  Other
# 5                                        None,  Other
# 6             220 Volt Outlet, Laundry Area - In Unit
# 7         Hookup - Gas Dryer, Hookups Only, In Closet
# 8                                           In Garage
# 9                                     In Laundry Room
# 10  220 Volt Outlet, In Laundry Room, Laundry Area...
# 11                                          In Closet
# 12                                          In Garage
# 13                                       Hookups Only
# 14                                    In Laundry Room
# 15                                 Hookup - Gas Dryer
# 16                                 Hookup - Gas Dryer
# 17                            Hookups Only, In Closet
# 18                            In Laundry Room,  Other
# 19                                          In Garage
#
#                                                  Pool         Style Beds Bath  \
# 0                                     None, Pool - No  Contemporary    3    3
# 1                                     None, Pool - No   Traditional    3    3
# 2                                     None, Pool - No         Ranch    3    3
# 3                                     None, Pool - No      Bungalow    3    3
# 4                                     None, Pool - No   Traditional    3    3
# 5                                     None, Pool - No     Craftsman    2    2
# 6                                     None, Pool - No  Contemporary    4    4
# 7                                     None, Pool - No   Traditional    3    3
# 8                               In Ground, Pool - Yes  Contemporary    3    3
# 9          Community Facility, In Ground, Spa/Hot Tub             –    3    3
# 10                                    None, Pool - No  Contemporary    4    4
# 11                                    None, Pool - No   Traditional    4    4
# 12                                    None, Pool - No  Contemporary    3    3
# 13                                    None, Pool - No         Ranch    3    3
# 14  Community Facility,  Gunite, Heated - Gas, Spa...             –    3    3
# 15                                                  –  Contemporary    4    4
# 16                                                  –  Contemporary    4    4
# 17                                    None, Pool - No  Contemporary    3    3
# 18                                    None, Pool - No   Traditional    3    3
# 19                                    None, Pool - No         Ranch    3    3
#
#     Sqft Sqft_Lot Year_Built
# 0   1581    5,928       1958
# 1   2086    3,847       2018
# 2   1800    5,005       1956
# 3   1037    5,454       1950
# 4   1301    5,005       1956
# 5   1080    7,645       1912
# 6   1474    1,210       1970
# 7   1886    9,680       1951
# 8   1336    1,600       1987
# 9   1536        –          –
# 10  2682     0.29       1992
# 11  1000    5,000       1944
# 12  1392    5,600       1958
# 13  1260    5,358       1959
# 14  1100        –          –
# 15  1909      836       2019
# 16  1909      836       2019
# 17  1581    5,928       1958
# 18  2086    3,847       2018
# 19  1800    5,005       1956

# %%
df['Sold_Price'] = df['Sold_Price'].astype(float)
df['Sqft'] = df['Sqft'].astype(float)

# %%
sns.barplot(x='Sold_Price',y='Style',data=df,orient='h')

# %% [markdown]
# Question 3: To furthermore explore in the style of the house, what is the sold price distribution of the style?
# Conclusion: Customer style is the most famous style in the hayward and the sold price is also maximum for this house.

# %%
df['Sold_Price'] = df['Sold_Price'].astype(float)

# %%
df.head(1)
# Out:
#                                  Address Sold_Price            Sold_Date  \
# 0  25026 Willimet Way, Hayward, CA 94544    815000   Sold on Mar 6, 2020
#
#                 House_Type                                           Bathroom  \
# 0  Single Family Residence  Shower(s) over Tub(s), Solid Surface,  Tile,  ...
#
#                                              Kitchen           Family_Room  \
# 0  Dishwasher, Garbage Disposal,  Microwave, Oven...  Separate Family Room
#
#                   Fire_Place         Flooring                  Laundry  \
# 0  Family Room, Wood Burning  Laminate,  Tile  Hookups Only, In Closet
#
#               Pool         Style Beds Bath   Sqft Sqft_Lot Year_Built
# 0  None, Pool - No  Contemporary    3    3  1,581    5,928       1958

# %% [markdown]
# Question 4: To explore the relationship between the change in the sold_price vs sqft in Hayward city?
# Conclusion: The Sqft is positively correlated with the change on the sold price. When the sqft of a house
# will increase than the house sold price will also increase.

# %%
sns.regplot('Sold_Price','Sqft',data=df)
plt.title('Changes in %s versus %s' %('Sold_Price','Sqft'))
# Out:
# Text(0.5, 1.0, 'Changes in Sold_Price versus Sqft')
